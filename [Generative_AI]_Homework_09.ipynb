# %% [markdown]
# <a href="https://colab.research.google.com/github/Guo0911/generative_ai/blob/main/%5BGenerative_AI%5D_Homework_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **利用 Bing 進行文字生圖**
# ## 風格：**浮世繪風格**
#
# 浮世繪（Ukiyo-e）是起源於日本江戶時代（17-19世紀）的傳統木版畫藝術形式。這種風格以其精緻的線條、平面化的構圖、鮮明的色彩區塊和獨特的透視法而聞名。
#
# 代表藝術家包括葛飾北齋（Katsushika Hokusai）、歌川廣重（Utagawa Hiroshige）和喜多川歌麿（Kitagawa Utamaro）。
#
# 浮世繪常描繪自然風景、花鳥、名勝古蹟、歷史人物和日常生活場景，以細膩的線條和和諧的色彩表現出深厚的東方美學底蘊。最著名的作品之一是葛飾北齋的《神奈川衝浪裡》（又稱《大波》）。

# %% [markdown]
# ---
#
# ### 四組 prompt 和生成的圖片：

# %% [markdown]
# 1. prompt：北齋風格的浮世繪作品，描繪一位站在斷橋上的武士凝視翻騰的海浪，浪花如爪般捲曲，遠處富士山若隱若現，天空呈深藍色調，有傳統木版畫的線條質感，畫面留白處點綴飄落的櫻花瓣
# ![prompt1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. prompt：歌川廣重風格的浮世繪，夜晚的雨中街景，油紙傘下的藝妓走過石板路，燈籠的光透過雨簾灑落，畫面有獨特的透視構圖，木版畫質感明顯，藍色與深褐色為主色調，邊緣有傳統日式花紋框架
# ![prompt2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. prompt：喜多川歌麿風格浮世繪，春季茶園採茶場景，農民們彎腰工作，遠處是起伏的山巒與飄渺雲霧，前景有盛開的梅花樹，色彩以綠色與土色為主，細膩描繪人物表情與動作，畫面帶有傳統木版畫的紋理與日式題款
# ![prompt3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 4. prompt：月岡芳年風格浮世繪，描繪傳統能劇表演場景，表演者戴著鬼面具，姿態誇張動態，背景是燭光照明的簡約舞台，觀眾剪影可見，使用大膽的紅黑對比色，線條銳利有力，具有濃厚的戲劇張力與神秘氛圍，邊緣有日式書法與印章
# ![prompt4.jpg](data:image/jpeg;base64,...)
